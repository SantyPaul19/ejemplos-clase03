# %%
import pandas as pd

# %%
# !pip install faker

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,51):
    lista.append(
        {'nombre': fake.name(),'apellido' : fake.last_name(), 'ciudad' : fake.city()}
    )

# %%
lista
# Out:
# [{'nombre': 'Matthew Tate', 'apellido': 'Miller', 'ciudad': 'Sylviahaven'},
#  {'nombre': 'Laura Brown', 'apellido': 'Alexander', 'ciudad': 'Lake Markbury'},
#  {'nombre': 'Amanda Richardson', 'apellido': 'Stokes', 'ciudad': 'Edwardstad'},
#  {'nombre': 'Barbara Gates', 'apellido': 'Carter', 'ciudad': 'Patriciaton'},
#  {'nombre': 'Stephen Sullivan', 'apellido': 'Huynh', 'ciudad': 'Candacefort'},
#  {'nombre': 'Kim Harris', 'apellido': 'Williams', 'ciudad': 'Christineton'},
#  {'nombre': 'Patrick Rose', 'apellido': 'Mahoney', 'ciudad': 'Michaelville'},
#  {'nombre': 'Michael Taylor',
#   'apellido': 'Phillips',
#   'ciudad': 'West Ronaldland'},
#  {'nombre': 'Caleb Watson', 'apellido': 'Ochoa', 'ciudad': 'Chadfort'},
#  {'nombre': 'Ashley Morgan',
#   'apellido': 'Anderson',
#   'ciudad': 'Christiechester'},
#  {'nombre': 'Lisa Powell',
#   'apellido': 'Williams',
#   'ciudad': 'East Robertbury'},
#  {'nombre': 'Shawn Snow', 'apellido': 'Sherman', 'ciudad': 'Maddoxshire'},
# ...

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                  nombre   apellido             ciudad
# 0          Matthew Tate     Miller        Sylviahaven
# 1           Laura Brown  Alexander      Lake Markbury
# 2     Amanda Richardson     Stokes         Edwardstad
# 3         Barbara Gates     Carter        Patriciaton
# 4      Stephen Sullivan      Huynh        Candacefort
# 5            Kim Harris   Williams       Christineton
# 6          Patrick Rose    Mahoney       Michaelville
# 7        Michael Taylor   Phillips    West Ronaldland
# 8          Caleb Watson      Ochoa           Chadfort
# 9         Ashley Morgan   Anderson    Christiechester
# 10          Lisa Powell   Williams    East Robertbury
# 11           Shawn Snow    Sherman        Maddoxshire
# 12          James Perry     Garcia        Bishopshire
# 13    Christopher Smith      Nunez          Drakeport
# 14          Donna Mills       Cook         Davisshire
# 15          Scott Reyes    Jackson        Port Jeanne
# ...

# %%
data.to_csv("misdata3.csv", index=False)
